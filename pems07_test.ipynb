# %%
import numpy as np

data = np.load("PEMS07.npz")

print(data.files)
print(data["data"].shape)
# Out:
# ['data']
# (28224, 883, 1)

# %%
traffic = data["data"]

# if last dimension exists
if len(traffic.shape) == 3:
    traffic = traffic[:, :, 0]

print(traffic.shape)
# Out:
# (28224, 883)

# %%
print(traffic.nbytes / 1024 / 1024, "MB")
# Out:
# 190.13818359375 MB
